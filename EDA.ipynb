# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
# read the file
bbh = pd.read_csv("E://Users//PC//Anaconda3//Dataset//archive//BillboardFromLast20//billboardHot100_1999-2019.csv")
print('The data shape of billboardHot100_1999-2019 is : ', bbh.shape)
# Out:
# The data shape of billboardHot100_1999-2019 is :  (97225, 12)

# %%
# Run the code to see the variables , then read the variables description below to understand them

bbh.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week              Date  \
# 0            1.0             7.0  2019-07-06     April 5, 2019
# 1            NaN             NaN  2019-07-06     June 21, 2019
# 2            2.0            13.0  2019-07-06    March 29, 2019
# 3            3.0            20.0  2019-07-06  February 7, 2019
# 4            2.0             7.0  2019-07-06      May 10, 2019
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# ...

# %%
# An numeric variable is one with values of integer or real numbers while a categorical variable is a variable
# than take on one of a limited and usually fixed , numbers of possible values 

bbh.describe()
# Out:
#          Unnamed: 0   Weekly.rank  Peak.position  Weeks.on.chart
# count  97225.000000  97225.000000    90156.00000    90156.000000
# mean   48613.000000     50.452373       36.58665       12.542948
# std    28066.584298     28.816813       27.36506        9.123191
# min        1.000000      1.000000        1.00000        0.000000
# 25%    24307.000000     26.000000       11.00000        6.000000
# 50%    48613.000000     50.000000       33.00000       11.000000
# 75%    72919.000000     75.000000       59.00000       17.000000
# max    97225.000000    100.000000      100.00000       87.000000

# %%
#Cleaning the data
bbh.isnull().sum()
# Out:
# Unnamed: 0             0
# Artists                0
# Name                   0
# Weekly.rank            0
# Peak.position       7069
# Weeks.on.chart      7069
# Week                   0
# Date               12247
# Genre                  0
# Writing.Credits     7213
# Lyrics                 0
# Features           75936
# dtype: int64

# %%
sns.heatmap(bbh.isnull(), xticklabels = True, yticklabels = False)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(bbh.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
billboard = bbh.drop(['Date', 'Features'], axis=1)

# %%
billboard.head()
# Out:
#    Unnamed: 0                       Artists           Name  Weekly.rank  \
# 0           1                      Lil Nas,  Old Town Road            1
# 1           2  Shawn Mendes, Camila Cabello       Senorita            2
# 2           3                 Billie Eilish        Bad Guy            3
# 3           4                        Khalid           Talk            4
# 4           5     Ed Sheeran, Justin Bieber   I Don't Care            5
#
#    Peak.position  Weeks.on.chart        Week  \
# 0            1.0             7.0  2019-07-06
# 1            NaN             NaN  2019-07-06
# 2            2.0            13.0  2019-07-06
# 3            3.0            20.0  2019-07-06
# 4            2.0             7.0  2019-07-06
#
#                                                Genre  \
# 0  Country,Atlanta,Alternative Country,Hip-Hop,Tr...
# 1                                                Pop
# 2  Hip-Hop,Dark Pop,House,Trap,Memes,Alternative ...
# ...

# %%
bbh.dropna(inplace = True)

# %%
sns.heatmap(bbh.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')
sns.countplot('Weekly.rank', data = bbh)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Weekly.rank', ylabel='count'>

# %%
sns.countplot(x = 'Weeks.on.chart', data = bbh)
# Out:
# <AxesSubplot:xlabel='Weeks.on.chart', ylabel='count'>

# %%
#relationalship analysis
correlation = bbh.corr()

# %%
sns.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(bbh)

# %%
sns.relplot(x = 'Weekly.rank', y ='Peak.position', data = bbh )

# %%
sns.distplot(bbh['Weeks.on.chart'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weeks.on.chart', ylabel='Density'>

# %%
sns.catplot(x = 'Peak.position', kind = 'box', data = bbh)

# %%
sns.catplot(x = 'Weeks.on.chart', kind = 'box', data = bbh)

# %%
#converting categorical features

bbh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18087 entries, 0 to 95235
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18087 non-null  int64
#  1   Name             18087 non-null  object
#  2   Weekly.rank      18087 non-null  int64
#  3   Peak.position    18087 non-null  float64
#  4   Weeks.on.chart   18087 non-null  float64
#  5   Week             18087 non-null  object
#  6   Date             18087 non-null  object
#  7   Writing.Credits  18087 non-null  object
#  8   Lyrics           18087 non-null  object
#  9   Features         18087 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 1.5+ MB

# %%
pd.get_dummies(bbh['Week'],drop_first = True).head()
# Out:
#     1999-12-20  1999-12-27  2000-01-03  2000-01-10  2000-01-17  2000-01-24  \
# 0            0           0           0           0           0           0
# 7            0           0           0           0           0           0
# 8            0           0           0           0           0           0
# 18           0           0           0           0           0           0
# 30           0           0           0           0           0           0
#
#     2000-01-31  2000-02-07  2000-02-14  2000-02-21  ...  2019-05-04  \
# 0            0           0           0           0  ...           0
# 7            0           0           0           0  ...           0
# 8            0           0           0           0  ...           0
# 18           0           0           0           0  ...           0
# 30           0           0           0           0  ...           0
#
#     2019-05-11  2019-05-18  2019-05-25  2019-06-01  2019-06-08  2019-06-15  \
# ...

# %%
wk = pd.get_dummies(bbh['Weeks.on.chart'], drop_first = True).head()
week = pd.get_dummies(bbh['Week'], drop_first = True)

# %%
bbh.drop(['Week', 'Weeks.on.chart', 'Date'], axis=1, inplace = True)

# %%
bbh.head()
# Out:
#     Unnamed: 0                Name  Weekly.rank  Peak.position  \
# 0            1       Old Town Road            1            1.0
# 7            8  Money In The Grave            8            7.0
# 8            9         No Guidance            9            9.0
# 18          19             Pop Out           19           11.0
# 30          31                 ME!           31            2.0
#
#                                       Writing.Credits  \
# 0   Jozzy, Atticus ross, Trent reznor, Billy ray c...
# 7   Asoteric, Ljay currie, Cydney christine, Rick ...
# 8   Velous, J louis, Vinylz, Michee patrick lebrun...
# 18                                   Lil tjay, Polo g
# 30            Brendon urie, Joel little, Taylor swift
#
#                                                Lyrics         Features
# 0   Old Town Road Remix \nOh, oh-oh\nOh\nYeah, I'm...  Billy Ray Cyrus
# 7   Money in the Grave \nYeah, okay\nLil CC on the...        Rick Ross
# ...
